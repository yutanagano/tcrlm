# %%
import sys
import os
sys.path.append('/home/yutanagano/Projects/tcr_embedder')
os.chdir('/home/yutanagano/Projects/tcr_embedder')

# %%
import pandas as pd
from pathlib import Path
import seaborn

seaborn.set_theme()
seaborn.set_style('white')

# %%
model_save_dir = Path('model_saves/CDR3BERT_cp_6_128_8_512')
metrics = pd.read_csv(model_save_dir/'log.csv')

# %%
seaborn.lineplot(metrics[['loss', 'valid_loss']])
# Out:
# <AxesSubplot: >

# %%
if 'valid_acc' in metrics.columns:
    ax = seaborn.lineplot(metrics[['valid_acc', 'valid_top5_acc']], palette=('tab:orange','tab:orange'))
    ax.set_ylim(0,1)

# %%
if 'valid_aln' in metrics.columns:
    seaborn.lineplot(metrics['valid_aln'])

# %%
if 'valid_unf' in metrics.columns:
    seaborn.lineplot(metrics['valid_unf'])
