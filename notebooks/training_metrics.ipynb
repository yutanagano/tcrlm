# %%
import sys
import os
sys.path.append('/home/yutanagano/Projects/tcr_embedder')
os.chdir('/home/yutanagano/Projects/tcr_embedder')

# %%
import pandas as pd
from pathlib import Path
import seaborn

seaborn.set_theme()
seaborn.set_style('white')

# %%
model_save_dir = Path('/home/yutanagano/UCLOneDrive/MBPhD/projects/tcr_embedder/model_saves/20221209-002000')
metrics = pd.read_csv(model_save_dir/'log.csv')

# %%
seaborn.lineplot(metrics[['loss', 'valid_simc_loss', 'valid_mlm_loss']])
# Out:
# <AxesSubplot: >

# %%
if 'lr' in metrics.columns:
    seaborn.lineplot(metrics['lr'])

# %%
if 'valid_mlm_acc' in metrics.columns:
    ax = seaborn.lineplot(metrics[['valid_mlm_acc']], palette=('tab:orange',))
    ax.set_ylim(0,1)

# %%
if 'valid_aln' in metrics.columns:
    seaborn.lineplot(metrics['valid_aln'])

# %%
if 'valid_unf' in metrics.columns:
    seaborn.lineplot(metrics['valid_unf'])
