# %%
import os
from pathlib import Path
import sys

if "__project_dir__" not in globals():
    __project_dir__ = Path.cwd().parents[1].resolve()

sys.path.append(__project_dir__)
os.chdir(__project_dir__)

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_theme()

# %%
df = pd.read_csv("/home/yutanagano/UCLOneDrive/MBPhD/projects/tcr_embedder/data/preprocessed/tanno/test.csv")
pgens = np.load("/home/yutanagano/UCLOneDrive/MBPhD/projects/tcr_embedder/data/preprocessed/tanno/test_pgens.npy")

# %%
plt.figure()
plt.hist(np.log10(pgens), range=[-20, -6], bins=100)
plt.show()
# Out:
# /tmp/ipykernel_20479/2464161186.py:2: RuntimeWarning: divide by zero encountered in log10
#   plt.hist(np.log10(pgens), range=[-20, -6], bins=100)
