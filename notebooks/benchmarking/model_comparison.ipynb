# %%
import os
from pathlib import Path
import sys

if '__project_dir__' not in globals():
    __project_dir__ = Path.cwd().parents[1].resolve()

sys.path.append(__project_dir__)
os.chdir(__project_dir__)

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import seaborn

seaborn.set_theme()
seaborn.set_style('white')

# %%
BENCHMARKING_PARENT_DIR = Path('benchmarks')

# %%
metric_dicts = [
    {
        'model_name': 'random_guess',
        '5nn_accuracy': 1/48
    }
]

for model in BENCHMARKING_PARENT_DIR.iterdir():
    with open(model/'metrics.json', 'r') as f:
        metric_dicts.append(json.load(f))

# %%
metrics = pd.DataFrame(metric_dicts)
metrics = metrics.sort_values(by='5nn_accuracy', ignore_index=True)

# %%
metrics
# Out:
#                                            model_name  5nn_accuracy  \
# 0                                        random_guess      0.020833
# 1                                   random_embedder_4      0.113750
# 2                                   random_embedder_2      0.119375
# 3                                    atchley_embedder      0.122083
# 4                                   random_embedder_0      0.126667
# 5                                   random_embedder_3      0.128958
# 6                                   random_embedder_1      0.132500
# 7                      CDR3BERT_a_6_128_8_512-embed_5      0.208542
# 8                     CDR3BERT_ac_6_128_8_512-embed_5      0.237917
# 9                                    cdr3_levenshtein      0.283542
# 10                   CDR3BERT_acp_6_128_8_512-embed_5      0.286875
# 11                    CDR3BERT_ap_6_128_8_512-embed_5      0.290208
# 12  AutoContrastive_CDR3BERT_SimCLoss_acp_6_128_8_512      0.336667
# 13  EpitopeContrastive_CDR3BERT_SimCLoss_acp_6_128...      0.339167
#
#     alignment  uniformity  alignment + uniformity
# 0         NaN         NaN                     NaN
# 1    1.118467   -1.139765               -0.021298
# 2    0.601325   -0.681504               -0.080180
# 3    0.972870   -0.980380               -0.007510
# 4    0.654111   -0.753785               -0.099674
# 5    0.785866   -0.876657               -0.090791
# 6    0.882768   -0.929465               -0.046697
# 7    0.711361   -0.837177               -0.125816
# 8    0.605934   -0.698529               -0.092595
# 9         NaN         NaN                     NaN
# 10   0.753471   -0.805676               -0.052205
# 11   0.743530   -0.829466               -0.085936
# 12   1.363106   -1.402354               -0.039248
# 13   1.270793   -1.311733               -0.040940

# %%
def collapse_names(name):
    groups = (
        'AutoContrastive_CDR3BERT',
        'EpitopeContrastive_CDR3BERT',
        'CDR3BERT_acp',
        'CDR3BERT_ap',
        'CDR3BERT_ac',
        'CDR3BERT_a',
        'random_embedder'
    )

    for group in groups:
        if group in name:
            return group
    
    return name

metrics['model_name'] = metrics['model_name'].map(collapse_names)

# %%
metrics
# Out:
#                      model_name  5nn_accuracy  alignment  uniformity  \
# 0                  random_guess      0.020833        NaN         NaN
# 1               random_embedder      0.113750   1.118467   -1.139765
# 2               random_embedder      0.119375   0.601325   -0.681504
# 3              atchley_embedder      0.122083   0.972870   -0.980380
# 4               random_embedder      0.126667   0.654111   -0.753785
# 5               random_embedder      0.128958   0.785866   -0.876657
# 6               random_embedder      0.132500   0.882768   -0.929465
# 7                    CDR3BERT_a      0.208542   0.711361   -0.837177
# 8                   CDR3BERT_ac      0.237917   0.605934   -0.698529
# 9              cdr3_levenshtein      0.283542        NaN         NaN
# 10                 CDR3BERT_acp      0.286875   0.753471   -0.805676
# 11                  CDR3BERT_ap      0.290208   0.743530   -0.829466
# 12     AutoContrastive_CDR3BERT      0.336667   1.363106   -1.402354
# 13  EpitopeContrastive_CDR3BERT      0.339167   1.270793   -1.311733
#
#     alignment + uniformity
# 0                      NaN
# 1                -0.021298
# 2                -0.080180
# 3                -0.007510
# 4                -0.099674
# 5                -0.090791
# 6                -0.046697
# 7                -0.125816
# 8                -0.092595
# 9                      NaN
# 10               -0.052205
# 11               -0.085936
# 12               -0.039248
# 13               -0.040940

# %%
knn_acc_plot = seaborn.barplot(metrics, x='model_name', y='5nn_accuracy')
knn_acc_plot.set_xticklabels(knn_acc_plot.get_xticklabels(), rotation=90)
plt.show()

# %%
knn_acc_plot = seaborn.barplot(metrics.iloc[:-2], x='model_name', y='5nn_accuracy')
knn_acc_plot.set_xticklabels(knn_acc_plot.get_xticklabels(), rotation=90)
plt.show()

# %%
scatter_model_names = seaborn.scatterplot(metrics, x='5nn_accuracy', y='alignment + uniformity', hue='model_name')
seaborn.move_legend(scatter_model_names, 'upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
scatter_model_names = seaborn.scatterplot(metrics, x='alignment', y='uniformity', hue='model_name')
seaborn.move_legend(scatter_model_names, 'upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
scatter_model_names = seaborn.scatterplot(metrics, x='alignment', y='uniformity', hue='5nn_accuracy')
seaborn.move_legend(scatter_model_names, 'upper left', bbox_to_anchor=(1, 1))
plt.show()
